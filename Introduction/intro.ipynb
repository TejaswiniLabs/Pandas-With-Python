# %% [markdown]
# ### Introduction:
# ### What are Pandas?

# %%
# Imagine you have student data:
# | Roll No | Name  | Age | Marks |
# | ------: | ----- | --: | ----: |
# |       1 | Aditi |  20 |    91 |
# |       2 | Rahul |  21 |    84 |
# |       3 | Neha  |  20 |    95 |
# Without Pandas, handling thousands of rows like this in plain Python becomes difficult.
# Pandas lets you:

# Read data from CSV, Excel, JSON, and SQL.
# Clean missing or incorrect values.
# Filter records.
# Sort data.
# Group and summarize information.
# Merge multiple datasets.
# Prepare data for machine learning.

# Think of it like Excel, but programmable with Python.

# %% [markdown]
# ### 🤔 Why Not Just Use NumPy?

# %%
# | NumPy                              | Pandas                              |
# | ---------------------------------- | ----------------------------------- |
# | Works with arrays                  | Works with tables                   |
# | Mostly numeric data                | Numeric + text + dates + mixed data |
# | Faster for mathematical operations | Easier for data analysis            |
# | No column names                    | Has row and column labels           |
# | Best for scientific computing      | Best for real-world datasets        |
